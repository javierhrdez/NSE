# %%
# cargar librerias
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime
import datetime
import missingno as msno
# %matplotlib inline
# Out:
# C:\Users\mafer\Anaconda3\lib\site-packages\statsmodels\tools\_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
pd.options.display.float_format = '{:.2f}'.format

# %%
df= pd.read_csv("/Users/mafer/Documents/Proyectos/RESAGEBURB_09CSV20.csv", encoding = "latin-1", error_bad_lines=False)
df.shape
# Out:
# C:\Users\mafer\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (178) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (65649, 229)

# %%
df.head()
# Out:
#    ï»¿ENTIDAD            NOM_ENT  MUN                                NOM_MUN  \
# 0           9  Ciudad de MÃ©xico    0  Total de la entidad Ciudad de MÃ©xico
# 1           9  Ciudad de MÃ©xico    2                           Azcapotzalco
# 2           9  Ciudad de MÃ©xico    2                           Azcapotzalco
# 3           9  Ciudad de MÃ©xico    2                           Azcapotzalco
# 4           9  Ciudad de MÃ©xico    2                           Azcapotzalco
#
#    LOC                       NOM_LOC  AGEB  MZA   POBTOT   POBFEM  ...  \
# 0    0           Total de la entidad  0000    0  9209944  4805017  ...
# 1    0           Total del municipio  0000    0   432205   227255  ...
# 2    1  Total de la localidad urbana  0000    0   432205   227255  ...
# 3    1             Total AGEB urbana  0010    0     3183     1695  ...
# 4    1                  Azcapotzalco  0010    1      159       86  ...
#
#   VPH_TELEF  VPH_CEL VPH_INTER VPH_STVP VPH_SPMVPI VPH_CVJ VPH_SINRTV  \
# 0   1898265  2536523   2084156  1290811     957162  568827      46172
# 1     96128   123961    105899    66399      50965   31801       1661
# 2     96128   123961    105899    66399      50965   31801       1661
# 3       741      772       692      313        221     145          8
# 4        45       42        39       18         13       6          *
#
#   VPH_SINLTC VPH_SINCINT VPH_SINTIC
# 0      77272      561128      10528
# 1       2869       22687        322
# 2       2869       22687        322
# 3         14         148          5
# 4          0           9          0
#
# [5 rows x 229 columns]

# %%
#cdmx entidad 9 209 944
#Dejamos unicamente datos de los agebs urbanos 
#ageb urbana 9,145,632
df_rec=df[df.NOM_LOC=='Total AGEB urbana']
df_rec.POBTOT.sum()
# Out:
# 9145632

# %% [markdown]
# ### Metodologia:
# Consiste en realizar un analisis por componentes principales a partir de tres indices socioeconomicos distintos,
# con el fin de obtener un solo puntaje que permite ordenar a las AGEB de acuerdo al nivel socioeconomico predominante

# %% [markdown]
# Los datos utilizados provienen del Censo de Población y Vivienda de 2020 realizado por el Instituto Nacional de Estadistica y Geografia (INEGI).

# %% [markdown]
# ![indices_nse.JPG](attachment:indices_nse.JPG)
